# %%
import geopandas

# %%
geopandas.read_file('../data/arkansas/unprocessed/cb_geo')
# Out:
#        STATEFP20 COUNTYFP20 TRACTCE20 BLOCKCE20          GEOID20      NAME20  \
# 0             05        051    011702      1003  050510117021003  Block 1003
# 1             05        051    012001      1005  050510120011005  Block 1005
# 2             05        099    090200      1031  050990902001031  Block 1031
# 3             05        051    010800      2011  050510108002011  Block 2011
# 4             05        051    011002      1007  050510110021007  Block 1007
# ...          ...        ...       ...       ...              ...         ...
# 136417        05        101    180200      1060  051011802001060  Block 1060
# 136418        05        143    011105      1000  051430111051000  Block 1000
# 136419        05        143    011103      2027  051430111032027  Block 2027
# 136420        05        143    010519      1010  051430105191010  Block 1010
# 136421        05        143    010112      2070  051430101122070  Block 2070
#
# ...

# %%
geopandas.read_file('../data/arkansas/unprocessed/ELECTION_PRECINCTS.gdb').plot('county_fips')
# Out:
# <AxesSubplot:>

# %%
geopandas.read_file

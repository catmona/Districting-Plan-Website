# %%
import geopandas
import pandas as pd

# %%
precincts_geo = geopandas.read_file('../data/washington/unprocessed/precincts_geo')
cb_geo = geopandas.read_file('../data/washington/unprocessed/cb_geo')
districts_geo = geopandas.read_file('../data/washington/unprocessed/districts_geo.geojson')

# %%
# Out:
#     OBJECTID STATEFP10 SLDUST12 GEOID10                     NAMELSAD10 LSAD10  \
# 0          1        53      001   53001   State Legislative District 1     LU
# 1          2        53      002   53002   State Legislative District 2     LU
# 2          3        53      003   53003   State Legislative District 3     LU
# 3          4        53      004   53004   State Legislative District 4     LU
# 4          5        53      005   53005   State Legislative District 5     LU
# 5          6        53      006   53006   State Legislative District 6     LU
# 6          7        53      007   53007   State Legislative District 7     LU
# 7          8        53      008   53008   State Legislative District 8     LU
# 8          9        53      009   53009   State Legislative District 9     LU
# 9         10        53      010   53010  State Legislative District 10     LU
# 10        11        53      011   53011  State Legislative District 11     LU
# ...

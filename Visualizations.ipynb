# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/1976-2020-house.csv')

# %%
data[data['state'] == 'WASHINGTON'][data[data['party'] =='DEMOCRAT']].groupby('district').sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-5abdf34757b6> in <module>
# ----> 1 data[data['state'] == 'WASHINGTON'][data[data['party'] =='DEMOCRAT']].groupby('district').sum()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3009         # Do we have a (boolean) DataFrame?
#    3010         if isinstance(key, DataFrame):
# -> 3011             return self.where(key)
#    3012
#    3013         # Do we have a (boolean) 1d indexer?
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9284         """
#    9285         other = com.apply_if_callable(other, self)
# -> 9286         return self._where(
#    9287             cond, other, inplace, axis, level, errors=errors, try_cast=try_cast
#    9288         )
#
# ...

# %%
data[data['state'] == 'WASHINGTON'][data['party'] =='REPUBLICAN'][data['year']==2020].groupby('district').sum()
# Out:
# <ipython-input-34-3bb99c50f726>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data['state'] == 'WASHINGTON'][data['party'] =='REPUBLICAN'][data['year']==2020].groupby('district').sum()
# <ipython-input-34-3bb99c50f726>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data['state'] == 'WASHINGTON'][data['party'] =='REPUBLICAN'][data['year']==2020].groupby('district').sum()
#           year  state_fips  state_cen  state_ic  special  writein  \
# district
# 1         2020          53         91        73        0        0
# 2         2020          53         91        73        0        0
# 3         2020          53         91        73        0        0
# 4         2020          53         91        73        0        0
# 5         2020          53         91        73        0        0
# 6         2020          53         91        73        0        0
# ...

# %%
340407 - 288977
# Out:
# 51430

# %%
demographics = pd.read_csv('data/Washington_District_all.csv')

# %%
demographics
# Out:
#                                                cdTopic      Subject  \
# 0                                               People  Sex and Age
# 1                                               People  Sex and Age
# 2                                               People  Sex and Age
# 3                                               People  Sex and Age
# 4                                               People  Sex and Age
# ..                                                 ...          ...
# 323  H Cell value changed by at least 2 percent but...          NaN
# 324  J Cell value changed by 5 percent or more by t...          NaN
# 325                  N Not available or not comparable          NaN
# 326  S Cell value withheld because it did not meet ...          NaN
# 327                                   X Not applicable          NaN
#
#                 Title District 01 Estimate District 01 MOE  \
# 0    Total population               791545    (+/- 13144 )
# ...
